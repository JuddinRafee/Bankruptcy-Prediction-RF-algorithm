# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df1 = pd.read_excel("C:/Users/User10/PycharmProjects/BPSversion1/skin/dataset/data64.xlsx")
df2 = pd.read_csv("C:/Users/User10/PycharmProjects/BPSversion1/skin/dataset/resultdata64.csv")

# %%
df1
# Out:
#     ID     Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# 0    1 -0.047250  0.021914 -0.479502 -0.188971  0.006633 -0.016047 -0.002986
# 1    2 -0.052601 -0.016568 -0.175990 -0.153471  0.007068 -0.018521  0.000176
# 2    3 -0.259217  0.046521  0.950983 -0.003660  0.006138 -0.016047 -0.039728
# 3    4  0.088328  0.017722 -0.540323 -0.194584  0.007411  0.025332  0.028561
# 4    5  0.011902  0.123401  0.730972  0.081123  0.008173 -0.000894  0.011519
# 5    6 -0.010750  0.086701 -0.346591 -0.181137 -0.003539 -0.016047  0.006358
# 6    7  0.111888 -0.062905 -0.142794 -0.097832  0.007441  0.003512  0.032656
# 7    8  0.088218 -0.046319 -0.100240 -0.134195  0.007406  0.067292  0.020495
# 8    9  0.062672  0.015089  1.097010 -0.037911  0.007220  0.034639  0.023357
# 9   10 -0.054596 -0.000543 -0.604758 -0.201822  0.006674  0.003128 -0.002917
# 10  11 -0.590725 -0.084276  0.011862 -0.093685  0.007753 -0.103490 -0.089049
#
# ...

# %%
df2
# Out:
#     Unnamed: 0     0     1
# 0            0  0.42  0.58
# 1            1  0.92  0.08
# 2            2  0.68  0.32
# 3            3  1.00  0.00
# 4            4  0.98  0.02
# 5            5  0.78  0.22
# 6            6  1.00  0.00
# 7            7  1.00  0.00
# 8            8  1.00  0.00
# 9            9  1.00  0.00
# 10          10  0.97  0.03

# %%
df2.rename( columns={'Unnamed: 0':'ResultIndex'}, inplace=True )

# %%
df2
# Out:
#     ResultIndex     0     1
# 0             0  0.42  0.58
# 1             1  0.92  0.08
# 2             2  0.68  0.32
# 3             3  1.00  0.00
# 4             4  0.98  0.02
# 5             5  0.78  0.22
# 6             6  1.00  0.00
# 7             7  1.00  0.00
# 8             8  1.00  0.00
# 9             9  1.00  0.00
# 10           10  0.97  0.03

# %%
df3 = pd.merge(df1, df2, right_index=True, left_index = True)

# %%
df3
# Out:
#     ID     Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# 0    1 -0.047250  0.021914 -0.479502 -0.188971  0.006633 -0.016047 -0.002986
# 1    2 -0.052601 -0.016568 -0.175990 -0.153471  0.007068 -0.018521  0.000176
# 2    3 -0.259217  0.046521  0.950983 -0.003660  0.006138 -0.016047 -0.039728
# 3    4  0.088328  0.017722 -0.540323 -0.194584  0.007411  0.025332  0.028561
# 4    5  0.011902  0.123401  0.730972  0.081123  0.008173 -0.000894  0.011519
# 5    6 -0.010750  0.086701 -0.346591 -0.181137 -0.003539 -0.016047  0.006358
# 6    7  0.111888 -0.062905 -0.142794 -0.097832  0.007441  0.003512  0.032656
# 7    8  0.088218 -0.046319 -0.100240 -0.134195  0.007406  0.067292  0.020495
# 8    9  0.062672  0.015089  1.097010 -0.037911  0.007220  0.034639  0.023357
# 9   10 -0.054596 -0.000543 -0.604758 -0.201822  0.006674  0.003128 -0.002917
# 10  11 -0.590725 -0.084276  0.011862 -0.093685  0.007753 -0.103490 -0.089049
#
# ...
